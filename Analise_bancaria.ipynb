# %%
import pandas as np

# %%
import pandas as pd

df = pd.read_csv("transacoes_bancarias.csv")

df.head()
# Out:
#    id_transacao  id_cliente tipo_transacao    valor       data_transacao  \
# 0             1         144          saque  4938.32  2025-02-06 03:23:00
# 1             2         143       deposito  1314.72  2025-02-20 18:45:00
# 2             3         106  transferencia  4173.77  2025-01-27 23:08:00
# 3             4         121       deposito  2987.08  2025-01-02 07:47:00
# 4             5         118  transferencia  1363.74  2025-01-18 00:03:00
#
#   conta_origem conta_destino      descricao
# 0      Conta H           NaN          Saque
# 1      Conta I           NaN       Depósito
# 2      Conta J       Conta G  Transferência
# 3      Conta D           NaN       Depósito
# 4      Conta D       Conta I  Transferência
